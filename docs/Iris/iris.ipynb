# %% [markdown]
# ## O Danych
#
# Zbiór danych zawiera informacje o trzech gatunkach irysów: Iris setosa, Iris versicolor, i Iris virginica.
#
# Dane obejmują pomiary czterech cech: długość i szerokość działki kielicha oraz długość i szerokość płatka.
#
# Każdy wiersz w zbiorze danych reprezentuje pojedynczy kwiat, a wartości pomiarów są podane w centymetrach.
#
# Zbiór składa się z 150 próbek, po 50 dla każdego gatunku, i jest szeroko stosowany jako podstawowy zbiór danych do
# testowania algorytmów klasyfikacji oraz w nauce o danych i uczeniu maszynowym.
#
# Kolumny:
# * **długość kielicha (sepal length)** - Długość kielicha w cm
# * **szerokość kielicha (sepal width)** - Szerokość kielicha w cm
# * **długość płatka (petal length)** - Długość płatka w cm
# * **szerokość płatka (petal width)** - Szerokość płatka w cm
# * **klasa (class)** - Klasa irysa (setosa, versicolor, virginica)

# %%
import pandas as pd

# %%
df = pd.read_csv('25__iris.csv', sep=",")
df
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                                5.1                               3.5
# 1                                4.9                               3.0
# 2                                4.7                               3.2
# 3                                4.6                               3.1
# 4                                5.0                               3.6
# ..                               ...                               ...
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# ...

# %%
df['klasa (class)']
df
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                                5.1                               3.5
# 1                                4.9                               3.0
# 2                                4.7                               3.2
# 3                                4.6                               3.1
# 4                                5.0                               3.6
# ..                               ...                               ...
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# ...

# %% [markdown]
# # Zobaczmy czy znajdują sie jakieś wartości brakujące

# %%
print(df.isnull().sum())
# Out:
# długość kielicha (sepal length)     0
# szerokość kielicha (sepal width)    0
# długość płatka (petal length)       0
# szerokość płatka (petal width)      0
# klasa (class)                       0
# dtype: int64

# %% [markdown]
# # Wniosek: Żadnych wartości brakujących, mamy pełne dane, możemy robić analizę

# %% [markdown]
# # średnia wartość wszytkich czterech zmiennych

# %%
pd.options.display.max_columns = None
df.groupby('klasa (class)').describe()
# Out:
#                 długość kielicha (sepal length)                               \
#                                           count   mean       std  min    25%
# klasa (class)
# Iris-setosa                                50.0  5.006  0.352490  4.3  4.800
# Iris-versicolor                            50.0  5.936  0.516171  4.9  5.600
# Iris-virginica                             50.0  6.588  0.635880  4.9  6.225
#
#                                szerokość kielicha (sepal width)         \
#                  50%  75%  max                            count   mean
# klasa (class)
# Iris-setosa      5.0  5.2  5.8                             50.0  3.418
# Iris-versicolor  5.9  6.3  7.0                             50.0  2.770
# Iris-virginica   6.5  6.9  7.9                             50.0  2.974
#
#                                                         \
#                       std  min    25%  50%    75%  max
# klasa (class)
# Iris-setosa      0.381024  2.3  3.125  3.4  3.675  4.4
# ...

# %%
agregacja = df.groupby('klasa (class)', as_index=False).agg(['mean','min', 'max', 'std'])
agregacja
# Out:
#                 długość kielicha (sepal length)                      \
#                                            mean  min  max       std
# klasa (class)
# Iris-setosa                               5.006  4.3  5.8  0.352490
# Iris-versicolor                           5.936  4.9  7.0  0.516171
# Iris-virginica                            6.588  4.9  7.9  0.635880
#
#                 szerokość kielicha (sepal width)                      \
#                                             mean  min  max       std
# klasa (class)
# Iris-setosa                                3.418  2.3  4.4  0.381024
# Iris-versicolor                            2.770  2.0  3.4  0.313798
# Iris-virginica                             2.974  2.2  3.8  0.322497
#
#                 długość płatka (petal length)                      \
#                                          mean  min  max       std
# klasa (class)
# Iris-setosa                             1.464  1.0  1.9  0.173511
# ...

# %%
df0 = df.groupby('klasa (class)', as_index=False).mean({'dl kielicha', 'sz kielicha', 'dl platka', 'sz platka', 'klasa'})
df0
# Out:
#      klasa (class)  długość kielicha (sepal length)  \
# 0      Iris-setosa                            5.006
# 1  Iris-versicolor                            5.936
# 2   Iris-virginica                            6.588
#
#    szerokość kielicha (sepal width)  długość płatka (petal length)  \
# 0                             3.418                          1.464
# 1                             2.770                          4.260
# 2                             2.974                          5.552
#
#    szerokość płatka (petal width)
# 0                           0.244
# 1                           1.326
# 2                           2.026

# %%
df.groupby('klasa (class)').count()
# Out:
#                  długość kielicha (sepal length)  \
# klasa (class)
# Iris-setosa                                   50
# Iris-versicolor                               50
# Iris-virginica                                50
#
#                  szerokość kielicha (sepal width)  \
# klasa (class)
# Iris-setosa                                    50
# Iris-versicolor                                50
# Iris-virginica                                 50
#
#                  długość płatka (petal length)  szerokość płatka (petal width)
# klasa (class)
# Iris-setosa                                 50                              50
# Iris-versicolor                             50                              50
# Iris-virginica                              50                              50

# %% [markdown]
# # mediana oraz wartość maxymalna i minimalna dla każdej zmiennej

# %%
df1 = df.groupby('klasa (class)', as_index=False).agg({
    'długość kielicha (sepal length)': ['min', 'median','max'],
    'szerokość kielicha (sepal width)': ['min', 'median','max'],
    'długość płatka (petal length)': ['min', 'median','max' ],
    'szerokość płatka (petal width)': ['min', 'median','max' ],
})
df1
# Out:
#      klasa (class) długość kielicha (sepal length)              \
#                                                min median  max
# 0      Iris-setosa                             4.3    5.0  5.8
# 1  Iris-versicolor                             4.9    5.9  7.0
# 2   Iris-virginica                             4.9    6.5  7.9
#
#   szerokość kielicha (sepal width)             długość płatka (petal length)  \
#                                min median  max                           min
# 0                              2.3    3.4  4.4                           1.0
# 1                              2.0    2.8  3.4                           3.0
# 2                              2.2    3.0  3.8                           4.5
#
#               szerokość płatka (petal width)
#   median  max                            min median  max
# 0   1.50  1.9                            0.1    0.2  0.6
# 1   4.35  5.1                            1.0    1.3  1.8
# ...

# %%
df.groupby('klasa (class)').median()
# Out:
#                  długość kielicha (sepal length)  \
# klasa (class)
# Iris-setosa                                  5.0
# Iris-versicolor                              5.9
# Iris-virginica                               6.5
#
#                  szerokość kielicha (sepal width)  \
# klasa (class)
# Iris-setosa                                   3.4
# Iris-versicolor                               2.8
# Iris-virginica                                3.0
#
#                  długość płatka (petal length)  szerokość płatka (petal width)
# klasa (class)
# Iris-setosa                               1.50                             0.2
# Iris-versicolor                           4.35                             1.3
# Iris-virginica                            5.55                             2.0

# %%
df.corr()
# Out:
# /tmp/ipykernel_886/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                   długość kielicha (sepal length)  \
# długość kielicha (sepal length)                          1.000000
# szerokość kielicha (sepal width)                        -0.109369
# długość płatka (petal length)                            0.871754
# szerokość płatka (petal width)                           0.817954
#
#                                   szerokość kielicha (sepal width)  \
# długość kielicha (sepal length)                          -0.109369
# szerokość kielicha (sepal width)                          1.000000
# długość płatka (petal length)                            -0.420516
# szerokość płatka (petal width)                           -0.356544
#
# ...

# %%
agg_df = df.groupby('klasa (class)', as_index=False).agg('mean')
agg_df
# Out:
#      klasa (class)  długość kielicha (sepal length)  \
# 0      Iris-setosa                            5.006
# 1  Iris-versicolor                            5.936
# 2   Iris-virginica                            6.588
#
#    szerokość kielicha (sepal width)  długość płatka (petal length)  \
# 0                             3.418                          1.464
# 1                             2.770                          4.260
# 2                             2.974                          5.552
#
#    szerokość płatka (petal width)
# 0                           0.244
# 1                           1.326
# 2                           2.026

# %% [markdown]
# # Obliczmy Średnią wartośc kielicha do płatka

# %%
df.plot(kind='scatter', x='długość kielicha (sepal length)', y='długość płatka (petal length)')
# Out:
# <Axes: xlabel='długość kielicha (sepal length)', ylabel='długość płatka (petal length)'>

# %%
df.plot(kind='scatter', x='długość kielicha (sepal length)', y='szerokość płatka (petal width)')
# Out:
# <Axes: xlabel='długość kielicha (sepal length)', ylabel='szerokość płatka (petal width)'>

# %% [markdown]
# # Wniosek: IM Dłuższy Kielich Tym Dłuższy Płatek

# %% [markdown]
# # Obliczenie dla każdego rodzaju kwiatu

# %%
df[df['klasa (class)'] == 'Iris-setosa'].plot(kind='scatter', x="długość płatka (petal length)", y='szerokość płatka (petal width)', title='Iris-setosa')
# Out:
# <Axes: title={'center': 'Iris-setosa'}, xlabel='długość płatka (petal length)', ylabel='szerokość płatka (petal width)'>

# %%
df[df['klasa (class)'] == 'Iris-versicolor'].plot(kind='scatter', x="długość płatka (petal length)", y='szerokość płatka (petal width)', title='Iris-versicolor')
# Out:
# <Axes: title={'center': 'Iris-versicolor'}, xlabel='długość płatka (petal length)', ylabel='szerokość płatka (petal width)'>

# %%
df[df['klasa (class)'] == 'Iris-virginica'].plot(kind='scatter', x="długość płatka (petal length)", y='szerokość płatka (petal width)', title='Iris-virginica')
# Out:
# <Axes: title={'center': 'Iris-virginica'}, xlabel='długość płatka (petal length)', ylabel='szerokość płatka (petal width)'>

# %% [markdown]
# # Wniosek: Iris Virginica ma najdłuższe i najgrubsze platki, potem jest Iris Versicolor i najmniejsze i najchudsze platki posiada Iris Setosa

# %%
df[df['klasa (class)'] == 'Iris-setosa'].plot(kind='scatter', x="długość kielicha (sepal length)", y='szerokość kielicha (sepal width)', title='Iris-setosa')
# Out:
# <Axes: title={'center': 'Iris-setosa'}, xlabel='długość kielicha (sepal length)', ylabel='szerokość kielicha (sepal width)'>

# %%
df[df['klasa (class)'] == 'Iris-versicolor'].plot(kind='scatter', x="długość kielicha (sepal length)", y='szerokość kielicha (sepal width)', title='Iris-versicolor')
# Out:
# <Axes: title={'center': 'Iris-versicolor'}, xlabel='długość kielicha (sepal length)', ylabel='szerokość kielicha (sepal width)'>

# %%
df[df['klasa (class)'] == 'Iris-virginica'].plot(kind='scatter', x="długość kielicha (sepal length)", y='szerokość kielicha (sepal width)', title='Iris-virginica')
# Out:
# <Axes: title={'center': 'Iris-virginica'}, xlabel='długość kielicha (sepal length)', ylabel='szerokość kielicha (sepal width)'>

# %%
df.groupby('klasa (class)').max().plot(kind='bar')
# Out:
# <Axes: xlabel='klasa (class)'>

# %% [markdown]
# # Wniosek: Szerokość kielicha Iris setosa jest wieksza od pozostalych

# %% [markdown]
# # Zobaczmy jakie są wartości odstające

# %%
df[df['klasa (class)'] == 'Iris-virginica'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-virginica')
# Out:
# /tmp/ipykernel_886/3745794163.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-virginica'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-virginica')
# <Axes: title={'center': 'Iris-virginica'}>

# %%
df[df['klasa (class)'] == 'Iris-virginica'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-virginica')
# Out:
# /tmp/ipykernel_886/489915601.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-virginica'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-virginica')
# <Axes: title={'center': 'Iris-virginica'}>

# %%
df[df['klasa (class)'] == 'Iris-versicolor'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-versicolor')
# Out:
# /tmp/ipykernel_886/1255521901.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-versicolor'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-versicolor')
# <Axes: title={'center': 'Iris-versicolor'}>

# %%
df[df['klasa (class)'] == 'Iris-versicolor'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-versicolor')
# Out:
# /tmp/ipykernel_886/347905148.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-versicolor'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-versicolor')
# <Axes: title={'center': 'Iris-versicolor'}>

# %%
df[df['klasa (class)'] == 'Iris-setosa'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-setosa')
# Out:
# /tmp/ipykernel_886/1152553075.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-setosa'][{'długość kielicha (sepal length)','szerokość kielicha (sepal width)'}].plot(kind='box',title='Iris-setosa')
# <Axes: title={'center': 'Iris-setosa'}>

# %%
df[df['klasa (class)'] == 'Iris-setoa'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-setosa')
# Out:
# /tmp/ipykernel_886/2304058819.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[df['klasa (class)'] == 'Iris-setoa'][{'długość płatka (petal length)','szerokość płatka (petal width)'}].plot(kind='box',title='Iris-setosa')
# <Axes: title={'center': 'Iris-setosa'}>

# %% [markdown]
# # Brak wartości odstających w Setosie analizując długość płatka do szerokości płatka

# %%
df.groupby('klasa (class)').plot(kind='box')
# Out:
# klasa (class)
# Iris-setosa        Axes(0.125,0.11;0.775x0.77)
# Iris-versicolor    Axes(0.125,0.11;0.775x0.77)
# Iris-virginica     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# # Podsumowanie:
# Z liczb powyzej i wykresow widzimy ze :
# najdluzsze i szerokie platki posiadaja Iris virginica potem versicolor i najmniejsze i najchudsze maja Iris Setosa
# ale za to Setosa ma najszerszy kielich potem jest virginica i versicolor,
# jeśli chodzi o długość kielicha to też najdluzzy jest Virginica potem Versicolor i na końcu Setosa.

# %% [markdown]
#  Setosa wyróżnia się szerokościa kielicha.
